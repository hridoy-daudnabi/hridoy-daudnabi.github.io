# %% [markdown]
# [Google Colab](https://colab.research.google.com/) is a hosted Jupyter notebook environment that allows anyone to run Python code via a web-browser. It provides you free computation and data storage that can be utilized by your Python code.
#
# You can click the `+Code` button to create a new cell and enter a block of code. To run the code, click the **Run Code** button next to the cell, or press `Shirt+Enter` key.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ### Package Management

# %% [markdown]
# Colab comes pre-installed with many Python packages. You can use a package by simply importing it.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# Each Colab notebook instance is run on a Ubuntu Linux machine in the cloud. If you want to install any packages, you can run a command by prefixing the command with a `!`. For example, you can install third-party packages via `pip` using the command `!pip`.
#
# > Tip: If you want to list all pre-install packages and their versions in your Colab environemnt, you can run `!pip list -v`.

# %%
# !pip install rioxarray

# %%
import rioxarray

# %% [markdown]
# ### Data Management

# %% [markdown]
# Colab provides 100GB of disk space along with your notebook. This can be used to store your data, intermediate outputs and results.
#
# The code below will create 2 folders named 'data' and 'output' in your local filesystem.

# %%
import os

data_folder = 'data'
output_folder = 'output'

if not os.path.exists(data_folder):
    os.mkdir(data_folder)
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %% [markdown]
# We can download some data from the internet and store it in the Colab environment. Below is a helper function to download a file from a URL.

# %%
import requests

def download(url):
    filename = os.path.join(data_folder, os.path.basename(url))
    if not os.path.exists(filename):
      with requests.get(url, stream=True, allow_redirects=True) as r:
          with open(filename, 'wb') as f:
              for chunk in r.iter_content(chunk_size=8192):
                  f.write(chunk)
      print('Downloaded', filename)

# %% [markdown]
# Let's download the [Populated Places](https://www.naturalearthdata.com/downloads/10m-cultural-vectors/) dataset from Natural Earth.

# %%
download('https://naciscdn.org/naturalearth/10m/cultural/' +
         'ne_10m_populated_places_simple.zip')

# %% [markdown]
# The file is now in our local filesystem. We can construct the path to the data folder and read it using `geopandas`

# %%
file = 'ne_10m_populated_places_simple.zip'
filepath = os.path.join(data_folder, file)
places = gpd.read_file(filepath)

# %%
places
# Out:
#       scalerank  natscale  labelrank              featurecla  \
# 0            10         1        8.0         Admin-1 capital
# 1            10         1        8.0         Admin-1 capital
# 2            10         1        8.0         Admin-1 capital
# 3            10         1        8.0         Admin-1 capital
# 4            10         1        8.0         Admin-1 capital
# ...         ...       ...        ...                     ...
# 7337          0       600        1.0         Admin-1 capital
# 7338          0       600        1.0         Admin-1 capital
# 7339          0       600        3.0         Admin-1 capital
# 7340          0       600        0.0         Admin-0 capital
# 7341          0       600        0.0  Admin-0 region capital
#
#                         name namepar              namealt  \
# 0     Colonia del Sacramento    None                 None
# 1                   Trinidad    None                 None
# 2                Fray Bentos    None                 None
# 3                  Canelones    None                 None
# 4                    Florida    None                 None
# ...                      ...     ...                  ...
# 7337          Rio de Janeiro    None                 None
# 7338               São Paulo    None  Sao Paulo|Sio Paulo
# 7339                  Sydney    None                 None
# 7340               Singapore    None                 None
# 7341               Hong Kong    None                 None
#
#                    nameascii  adm0cap  capalt  ...   pop_max   pop_min  \
# 0     Colonia del Sacramento        0       0  ...     21714     21714
# 1                   Trinidad        0       0  ...     21093     21093
# 2                Fray Bentos        0       0  ...     23279     23279
# 3                  Canelones        0       0  ...     19698     19698
# 4                    Florida        0       0  ...     32234     32234
# ...                      ...      ...     ...  ...       ...       ...
# 7337          Rio de Janeiro        0       0  ...  11748000   2010175
# 7338               Sao Paulo        0       0  ...  18845000  10021295
# 7339                  Sydney        0       0  ...   4630000   3641422
# 7340               Singapore        1       0  ...   5183700   3289529
# 7341               Hong Kong        0       0  ...   7206000   4551579
#
#        pop_other rank_max rank_min        meganame         ls_name min_zoom  \
# 0            0.0        7        7            None            None      9.0
# 1            0.0        7        7            None            None      9.0
# 2            0.0        7        7            None            None      9.0
# 3            0.0        6        6            None            None      9.0
# 4            0.0        7        7            None            None      7.0
# ...          ...      ...      ...             ...             ...      ...
# 7337   1821489.0       14       12  Rio de Janeiro  Rio de Janeiro      1.7
# 7338  11522944.0       14       14               S       Sao Paolo      3.0
# 7339   2669348.0       12       12          Sydney         Sydney1      1.7
# 7340   3314179.0       13       12       Singapore       Singapore      2.1
# 7341   4549026.0       13       12       Hong Kong       Hong Kong      3.0
#
#            ne_id                     geometry
# 0     1159112629  POINT (-57.83612 -34.46979)
# 1     1159112647      POINT (-56.901 -33.544)
# 2     1159112663      POINT (-58.304 -33.139)
# 3     1159112679      POINT (-56.284 -34.538)
# 4     1159112703      POINT (-56.215 -34.099)
# ...          ...                          ...
# 7337  1159151619  POINT (-43.21212 -22.90731)
# 7338  1159151621  POINT (-46.62697 -23.55673)
# 7339  1159151623  POINT (151.21255 -33.87137)
# 7340  1159151627    POINT (103.85387 1.29498)
# 7341  1159151629   POINT (114.18306 22.30693)
#
# [7342 rows x 32 columns]

# %% [markdown]
# Let's do some data processing and write the results to a new file. The code below will filter all places which are also country capitals.

# %%
capitals = places[places['adm0cap'] == 1]
capitals
# Out:
#       scalerank  natscale  labelrank       featurecla          name namepar  \
# 880           8        10        3.0  Admin-0 capital  Vatican City    None
# 4828          7        20        0.0  Admin-0 capital    San Marino    None
# 4833          7        20        0.0  Admin-0 capital         Vaduz    None
# 5012          6        30        8.0  Admin-0 capital    Luxembourg    None
# 6178          6        30        0.0  Admin-0 capital       Palikir    None
# ...         ...       ...        ...              ...           ...     ...
# 7330          0       600        3.0  Admin-0 capital         Cairo    None
# 7332          0       600        2.0  Admin-0 capital         Tokyo    None
# 7334          0       600        3.0  Admin-0 capital         Paris    None
# 7335          0       600        3.0  Admin-0 capital      Santiago    None
# 7340          0       600        0.0  Admin-0 capital     Singapore    None
#
#          namealt     nameascii  adm0cap  capalt  ...   pop_max  pop_min  \
# 880         None  Vatican City        1       0  ...       832      832
# 4828        None    San Marino        1       0  ...     29579    29000
# 4833        None         Vaduz        1       0  ...     36281     5342
# 5012        None    Luxembourg        1       0  ...    107260    76684
# 6178        None       Palikir        1       0  ...      4645     4645
# ...          ...           ...      ...     ...  ...       ...      ...
# 7330  Al-Qahirah         Cairo        1       0  ...  11893000  7734614
# 7332        None         Tokyo        1       0  ...  35676000  8336599
# 7334        None         Paris        1       0  ...   9904000    11177
# 7335        None      Santiago        1       0  ...   5720000    46611
# 7340        None     Singapore        1       0  ...   5183700  3289529
#
#        pop_other rank_max rank_min    meganame       ls_name min_zoom  \
# 880     562430.0        2        2        None  Vatican City      7.0
# 4828         0.0        7        7        None    San Marino      6.1
# 4833     33009.0        7        5        None         Vaduz      6.7
# 5012    106219.0        9        8        None    Luxembourg      6.0
# 6178         0.0        4        4        None       Palikir      6.0
# ...          ...      ...      ...         ...           ...      ...
# 7330  13720557.0       14       13  Al-Qahirah         Cairo      1.7
# 7332  12945252.0       14       13       Tokyo         Tokyo      1.7
# 7334   7142744.0       13        6       Paris         Paris      1.7
# 7335   3066651.0       13        7    Santiago     Santiago3      2.0
# 7340   3314179.0       13       12   Singapore     Singapore      2.1
#
#            ne_id                    geometry
# 880   1159127243   POINT (12.45339 41.90328)
# 4828  1159146051    POINT (12.44177 43.9361)
# 4833  1159146061    POINT (9.51667 47.13372)
# 5012  1159146437       POINT (6.13 49.61166)
# 6178  1159149061   POINT (158.14997 6.91664)
# ...          ...                         ...
# 7330  1159151603   POINT (31.24802 30.05191)
# 7332  1159151609  POINT (139.74946 35.68696)
# 7334  1159151613    POINT (2.35299 48.85809)
# 7335  1159151615  POINT (-70.6505 -33.44021)
# 7340  1159151627   POINT (103.85387 1.29498)
#
# [200 rows x 32 columns]

# %% [markdown]
# We can write the results to the disk as a GeoPackage file.

# %%
output_file = 'capitals.gpkg'
output_path = os.path.join(output_folder, output_file)
capitals.to_file(driver='GPKG', filename=output_path)

# %% [markdown]
# You can open the **Files** tab from the left-hand panel in Colab and browse to the `output` folder. Locate the `capitals.gpkg` file and click the **⋮** button and select *Download* to download the file locally.
